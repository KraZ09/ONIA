# %%
# Out:
# Vectorizing...
# Train shape: (3415, 46866)
# Fitting stacking classifier...
# /home/kraz09/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kraz09/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:1258: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 106
#      97 stack = StackingClassifier(
#      98     estimators=[('svc', svc), ('lr', lr), ('cnb', cnb), ('sgd', sgd)],
#      99     final_estimator=LogisticRegression(C=2, max_iter=1000, solver='lbfgs'),
#    (...)    102     n_jobs=-1,
#     103 )
#     105 print("Fitting stacking classifier...")
# --> 106 stack.fit(X_train, y)
# ...
